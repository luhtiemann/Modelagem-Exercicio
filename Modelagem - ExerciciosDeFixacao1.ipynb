# %% [markdown]
# Grupo:
#
# *   Luana Tiemann Halicki Cordeiro
# *   Alexandre Cicero Araujo Beiruth
# *   Leandro Cardoso Vieira
# *   João Vitor Gabardo da Cunha

# %% [markdown]
# 1. Um   fotógrafo   está   posicionado   em   frente   a   uma   plataforma   de lançamento de foguetes de forma que o eixo da lente da sua câmera está a 50 m de distância eperfeitamente alinhada com a base do foguete. Em que ângulo ele deve colocar a câmera para tirar uma foto deste foguete quando ele  estiver há  200  m  de  altura.

# %%
#importando as bibliotecas
import matplotlib.pyplot as plt #para graficos
import numpy as np #funções numéricas referentes a manipulaçao de vetores, matrizes e tensores. Trata-se de uma biblioteca de objetos, métodos e tipos de dados específicamente desenvolvida para uso em computação científica, cálculo numérico e álgebra linear que encontrou um nicho em aplicações de algoritmos de aprendizagem de máquina
from numpy import sin, cos, pi, linspace
import math #funcoes matematicas
print("OK")
# Out:
# OK

# %% [markdown]
# (a) encontrar o ângulo 𝑼, usando a linguagem de programação Python,    sem    usar    nenhuma    função    trigonométrica    disponível    na linguagem,  ou  em  suas  bibliotecas;

# %%
adj = 50
op = 200

x = op/adj
ang = math.degrees(math.atan(x))

print("Ângulo U = ", ang, "°")
# Out:
# Ângulo U =  75.96375653207353 °

# %% [markdown]
# (b) criar  uma  função  em  Python  que ajude o fotógrafo a ajustar o ângulo da câmera para qualquer altitude

# %%
adj = float(input("Insira o valor da distância da base foguete: "))
op = float(input("Insira o valor da altura do foguete: "))

def ajustarAngulo(adj,op):
  x = op/adj
  ang = math.degrees(math.atan(x)) #transforma para graus
  print("\nÂngulo da câmera = ", ang, "°")

ajustarAngulo(adj,op)
# Out:
# Insira o valor da distância da base foguete: 5000
# Insira o valor da altura do foguete: 1500
#
# Ângulo da câmera =  16.69924423399362 °

# %% [markdown]
# c) plotar, usando a biblioteca Matplotlib um diagrama do triângulo resultante em cada altitude.

# %%
plt.close('all') #só para ter certeza

plt.figure(figsize = (10, 5))
# Definindo um triangulo 3,4,5
x1=np.array([0,adj,adj,0]) #array de pontos
y1=np.array([0,0,op,0])

# desenhando a figura e os eixos
fig1=plt.figure(1)
ax1=fig1.add_subplot(111)

# Triângulo
ax1.axis('square')
plt.plot(x1,y1,color="purple") #plota os segmentos de reta

# deteminando o limite do eixos na figura
plt.xlim([-10,adj+10])
plt.ylim([-10,op+10])

# desenhando uma grade cinza para servir de base
plt.grid(axis='both',which='major',color=(0.8, 0.8, 0.8, 0.5), linestyle='-', linewidth=1)
plt.minorticks_on()
plt.grid(axis='both',which='minor',color=(0.8, 0.8, 0.8, 0.5), linestyle=':', linewidth=1)

plt.show() # mostra figura na tela

# %% [markdown]
# 2. O  código  de  construção civil  determina  a  inclinação  mínima  dos  telhados de  acordo  com o clima  da  região.  Na  maior  parte  das  vezes  esta  inclinação  mínima  é  para  evitar  excesso  de peso  sobre  a  estrutura  no  caso  de  chuva,  ou  neve. No  Brasil,  a  inclinação  de  telhados  é determinada pela norma NBR 5720 que permite algumas variações de acordo com o tipo de telha escolhido para a cobertura. No caso de telhas cerâmicas, a norma que deve ser utilizada é  a  norma NBR  8039.  Esta  norma  determina  que  a  inclinação  mínima  para  cada  telhado deverá ser de 25%. Sabendo que este percentual relaciona a altura com o comprimento do telhado,calcule a altura que um telhado com 3 m deverá ter para atender esta norma.

# %% [markdown]
# (a) encontrar a altura solicitada, usando a linguagem  de programação  Python, sem  usar  nenhuma  função  trigonométrica  disponível na  linguagem,  ou  em  suas  bibliotecas;

# %%
inc = 0.25
comp = 300

alt = inc * comp
print("Altura: ", alt, "cm")
# Out:
# Altura:  75.0 cm

# %% [markdown]
# (b)  criar  uma  função  em  Python  que  ajude os engenheiros e arquitetos a definir a altura do telhado de acordo com o seu comprimento

# %%
inc = float(input("Informe a inclinação do telhado em decimais: "))
comp = float(input("Informe o comprimento do telhado em centímetros: "))

alt = inc * comp
print("\nAltura: ", alt,  "cm")
# Out:
# Informe a inclinação do telhado em decimais: 0.1
# Informe o comprimento do telhado em centímetros: 500
#
# Altura:  50.0 cm

# %% [markdown]
# (c)  plotar,  usando  a  biblioteca  Matplotlib  um  diagrama  do  triângulo mostrando  a  altura necessária e o ângulo para cada comprimento de telhado entre 2 e 7m.

# %%
plt.close('all') #só para ter certeza
inc = 0.25
comp = 200

for i in range (6):
  
  alt = inc * comp
  x = alt/comp
  ang = math.degrees(math.atan(x))

  # Definindo um triangulo
  x1=np.array([0,comp,comp/2,0]) #array de pontos
  y1=np.array([0,0,alt,0]) 

  # desenhando a figura e os eixos
  fig1=plt.figure(1)
  ax1=fig1.add_subplot(111)

  # Triângulo
  ax1.axis('square')
  plt.plot(x1,y1,color="purple") #plota os segmentos de reta
  plt.plot([comp/2, comp/2], [0, alt], color = 'black')
  plt.gca().annotate(f'Ângulo:{ang:.2f}°', xy= (comp/6,alt/10))
  plt.gca().annotate(f'Altura:{alt:.0f}cm', xy= (comp/2+comp/50,alt/9))

  # deteminando o limite do eixos na figura
  plt.xlim([-50,comp+50])
  plt.ylim([-50,alt+50])

  # desenhando uma grade cinza para servir de base
  plt.grid(axis='both',which='major',color=(0.8, 0.8, 0.8, 0.5), linestyle='-', linewidth=1)
  plt.minorticks_on()
  plt.grid(axis='both',which='minor',color=(0.8, 0.8, 0.8, 0.5), linestyle=':', linewidth=1)

  print("Ângulo:",ang,"°")
  print("Altura:", alt, "cm")
  print("Comprimento:",comp, "cm")

  plt.show() # mostra figura na tela

  comp = comp+100
# Out:
# Ângulo: 14.036243467926479 °
# Altura: 50.0 cm
# Comprimento: 200 cm
# Ângulo: 14.036243467926479 °
# Altura: 75.0 cm
# Comprimento: 300 cm
# Ângulo: 14.036243467926479 °
# Altura: 100.0 cm
# Comprimento: 400 cm
# Ângulo: 14.036243467926479 °
# Altura: 125.0 cm
# Comprimento: 500 cm
# Ângulo: 14.036243467926479 °
# Altura: 150.0 cm
# Comprimento: 600 cm
# Ângulo: 14.036243467926479 °
# Altura: 175.0 cm
# Comprimento: 700 cm

# %% [markdown]
# 3. Usando o Python e as funções trigonométricas disponíveis nesta linguagem de programação e suas bibliotecas crie uma função que receba um ângulo, em graus, e plote um circulo trigonométrico de raio 1, centrado na origem destacando este ângulo, seu seno, seu cosseno e sua tangente.

# %%
def circTrig():

  plt.close('all') #só para ter certeza

  ang = float(input("Insira o ângulo desejado: "))

  #transforma para radianos
  s = math.sin(math.radians(ang)) 
  c = math.cos(math.radians(ang))
  t = math.tan(math.radians(ang))

  print(f"Ângulo: {ang}\nSeno: {s:.2f}\nCosseno: {c:.2f}\nTangente: {t:.2f}.")

  # cria uma figura de 18x7 polegadas
  plt.figure(figsize = (18, 7))

  #origem
  plt.plot(0,0, color = 'black', marker = 'o')

  #circulo
  angles = linspace(0*pi, 2*pi, 100 )
  xs = cos(angles)
  ys = sin(angles)
  plt.plot(xs, ys, color = 'black')

  #raio
  plt.plot(1, 0, marker = 'o', color = 'green')
  plt.plot([0, 1], [0, 0], color = 'black')

  #arco
  arc_angles = linspace(0, math.radians(ang), 20)
  arc_xs = cos(arc_angles)
  arc_ys = sin(arc_angles)
  plt.plot(arc_xs, arc_ys, color = 'green', lw = 3)

  #outro raio
  plt.plot(cos(math.radians(ang)), sin(math.radians(ang)), marker = 'o', color = 'green')
  plt.plot([0, cos(math.radians(ang))], [0, sin(math.radians(ang))], color = "green", label="ângulo")

  #ângulo
  r1 = 0.25
  arc_angles = linspace(0 * pi, math.radians(ang), 20)
  arc_xs = r1 * cos(arc_angles)
  arc_ys = r1 * sin(arc_angles)
  plt.plot(arc_xs, arc_ys, color = 'green', lw = 3)

  #seno
  plt.plot(0, s, marker = 'o', color = 'purple')
  plt.plot([0, 0], [0, s], color = 'purple', label = "seno")

  #cosseno
  plt.plot(c, 0, marker = 'o', color = 'blue')
  plt.plot([c, 0], [0, 0], color = 'blue', label = "cosseno")

  #tangente
  plt.plot(1, 0, marker = 'o', color = 'red')
  plt.plot(1, t, marker = 'o', color = 'red')
  plt.plot([1,1], [0, t], color = 'red', label = "tangente")

  #limites
  plt.xlim(-2, 2)
  plt.ylim(-2, 2)
  plt.gca().set_aspect('equal')
  plt.legend(loc='upper left')

  plt.show()

circTrig()
# Out:
# Insira o ângulo desejado: 15
# Ângulo: 15.0
# Seno: 0.26
# Cosseno: 0.97
# Tangente: 0.27.

# %% [markdown]
# 4. Usando o Python e as funções trigonométricas disponíveis nesta linguagem de programação e suas bibliotecas crie uma função que receba um número inteiro 𝑛 tal que 1 ≤ 𝑛 ≤ 5 e plote as funções seno, cosseno e tangente para todos os ângulos possíveis considerando que 𝑛 representa o número períodos completos.

# %%
from pickle import TRUE

def Periodos():
  plt.close('all') #só para ter certeza
  plt.figure(figsize = (10, 5)) #tamanho da figura

  while TRUE:
    n = int(input("Insira o um número de períodos completos, sendo um inteiro maior ou igual a 1 e menor ou igual a 5: ")) #input
    if n>=1 and n<=5: #limite do input

      x = np.linspace(0, 2*n*pi, 300) #cria uma sequencia de números uniformemente espaçados entre os limites dados
      c = np.cos(x) #calcula seno, cosseno, tangente
      s = np.sin(x)
      t = np.tan(x) 

      t[:-1][np.diff(t) < 0] = np.nan #how to plot tan without connecting line

      plt.plot(x, s, color="purple", label = "seno") #plotar, sequencia de numeros, seno, cor, legenda
      plt.plot(x, c, color="blue", label = "cosseno")
      plt.plot(x, t, color="red", label = "tangente") 
      plt.legend(loc='upper left')

      plt.yticks([-1, 0, +1],[r'$-1$', r'$0$', r'$+1$']) #valores laterais

      plt.xlim(0, 2*n*pi) #limites
      plt.ylim(-1.5, 1.5)  

      plt.show()

      break

    else:
      print("Insira um número entre 1 e 5")

  
Periodos()
# Out:
# Insira o um número de períodos completos, sendo um inteiro maior ou igual a 1 e menor ou igual a 5: 1
